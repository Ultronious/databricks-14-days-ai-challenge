# %%
# Day 1 – Databricks Platform Basics

**Goal:**  
Understand Databricks workspace, Spark basics, and run first PySpark commands.

**Topics covered:**
- Databricks vs Pandas/Hadoop
- Lakehouse basics
- Workspace structure
- First PySpark DataFrame operations

# %%
pip install kaggle

# %%
import os

os.environ["KAGGLE_USERNAME"] = "your_username"
os.environ["KAGGLE_KEY"] = "your_key"

print("Kaggle credentials configured!")

# %%
spark.sql("""
CREATE SCHEMA IF NOT EXISTS workspace.ecommerce
""")

# %%
spark.sql("""
CREATE VOLUME IF NOT EXISTS workspace.ecommerce.ecommerce_data
""")

# %%
# %sh
cd /Volumes/workspace/ecommerce/ecommerce_data
kaggle datasets download -d mkechinov/ecommerce-behavior-data-from-multi-category-store

# %%
# %sh
cd /Volumes/workspace/ecommerce/ecommerce_data
unzip -o ecommerce-behavior-data-from-multi-category-store.zip
ls -lh

# %%
# %sh
cd /Volumes/workspace/ecommerce/ecommerce_data
rm -f ecommerce-behavior-data-from-multi-category-store.zip
ls -lh

# %%
# %restart_python

# %%
df_n = spark.read.csv("/Volumes/workspace/ecommerce/ecommerce_data/2019-Nov.csv")

# %%
df = spark.read.csv("/Volumes/workspace/ecommerce/ecommerce_data/2019-Oct.csv")

# %%
print(f"October 2019 - Total Events: {df.count():,}")
print("\n" + "="*60)
print("SCHEMA:")
print("="*60)
df.printSchema()

# %%
print("\n" + "="*60)
print("SAMPLE DATA (First 5 rows):")
print("="*60)
df.show(10, truncate=False)

# %%
# Create simple DataFrame
data = [("iPhone", 999), ("Samsung", 799), ("MacBook", 1299), ("AirPods", 199), ("Apple Watch", 399), ("iMac", 2499), ("iPad", 799), ("Apple TV", 199), ("Ryzen5 7600x", 599), ("Ryzen5 5600x", 399), ("Ryzen5 3600", 299), ("Ryzen5 3600x", 399), ("Ryzen7 3600", 399), ("Ryzen7 3700x", 499), ("Ryzen7 5700x", 599), ("Ryzen7 5800x", 699), ("Ryzen9 5950x", 799), ("Ryzen9 7950x", 999), ("Ryzen9 7950x", 999), ("Ryzen9 7950x", 999), ("Ryzen9 7950x",  999), ("Ryzen9 7950x", 999), ("Ryzen9 7950x", 999), ("Ryzen9 7950x", 999), ("Ryzen9 7950x", 999), ("Ryzen9 7950x", 999), ("OnePlus 9 Pro", 1099), ("OnePlus 9", 899), ("OnePlus 9R", 799), ("OnePlus Nord", 499), ("OnePlus Nord 2", 599), ("OnePlus Nord 2T", 699), ("OnePlus Nord 2T 5G", 799), ("OnePlus Nord 2T 5G", 799), ("OnePlus Nord 2T 5G", 799), ("OnePlus Nord 2T 5G", 799), ("OnePlus Nord 2T 5G", 799), ("OnePlus Nord 2T 5G", 799), ("OnePlus Nord 2T 5G", 799), ("OnePlus Nord 2T 5G", 799)]
df = spark.createDataFrame(data, ["product", "price"])
df.show()

# Filter expensive products
df.filter(df.price > 1000).show()
df.filter(df.price<800).show()
df.filter(df.product=="Ryzen9 7950x").show()

# %% [markdown]
# # Step-by-step Comments for Cells 1–14
#
# **Cell 1:** Introduction and learning goals for Day 1, outlining Databricks basics and PySpark operations.
#
# **Cell 2:** Installs the Kaggle package to enable dataset downloads from Kaggle.
#
# **Cell 3:** Sets Kaggle API credentials so you can authenticate and download datasets securely.
#
# **Cell 4:** Creates a schema (database) in Unity Catalog for organizing your data assets.
#
# **Cell 5:** Creates a volume in Unity Catalog, providing a managed storage location for your data files.
#
# **Cell 6:** Changes directory to the volume and downloads the ecommerce dataset from Kaggle using shell commands.
#
# **Cell 7:** Unzips the downloaded dataset and lists files to confirm successful extraction.
#
# **Cell 8:** Cleans up by removing the zip file and listing files to verify only the extracted data remains.
#
# **Cell 9:** Restarts the Python kernel to ensure a clean environment for subsequent steps.
#
# **Cell 10:** Reads the November 2019 CSV data into a Spark DataFrame for analysis.
#
# **Cell 11:** Reads the October 2019 CSV data into a Spark DataFrame for analysis.
#
# **Cell 12:** Prints the total number of events and the schema for the October data, helping you understand the dataset structure.
#
# **Cell 13:** Displays a sample of the October data to preview its contents and check for data quality issues.
#
# **Cell 14:** Creates a simple DataFrame of products and prices, then demonstrates filtering operations to show how to select expensive, affordable, or specific products using PySpark.
#
# These comments clarify the purpose of each step and help users follow the workflow from data acquisition to basic analysis.
